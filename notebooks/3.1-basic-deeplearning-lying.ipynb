# %% [markdown]
# # Experiment 3.1: Basic deep learning on lying videos
#
# * input: lying video
# * Output: Left/right leg amplitude/duration (4 scores)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import tensorflow.keras as keras

from src.helpers import read_scores
from src.data_generators import RawDataGenerator
from src.data_selection import MultipleScoreSelector
from src.ai_func import cross_validation_generator
from src.settings import LYING_VIDEOS_DATA_FOLDER, SITTING_VIDEOS_DATA_FOLDER, DATA_FOLDER

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Read metadata

# %%
scores_df = read_scores(DATA_FOLDER / 'data_Scoring_DIS_proximal_trunk_V1.1.xlsx')

# %% [markdown]
# ## Definitions

# %%
SCORES_TO_USE = ['D_RLP_R_tD_pscore', 'D_LLP_R_tD_pscore', 'D_RLP_R_tA_pscore', 'D_LLP_R_tA_pscore']
SCORERS = [1, 2, 3]

# %% [markdown]
# ## Pipeline for training a deep neural network

# %% [markdown]
# ### Define model architecture (here: simple CNN)

# %%
# Generate some dev data to get X shape
dev_selection = selector.transform(scores_df)
dev_generator = RawDataGenerator(dev_selection, videos_folder=LYING_VIDEOS_DATA_FOLDER)
X, y = dev_generator.__getitem__(0)
n_timesteps, n_features = (X.shape[1], X.shape[2])
# Out:
# /Users/svenvanderburg/projects/modys-video/src/data_selection.py:24: UserWarning: Dropping rows ['096'] with missing video
#   warnings.warn(f'Dropping rows {missing_ids} with missing video')
# /Users/svenvanderburg/projects/modys-video/src/data_selection.py:34: UserWarning: Dropping rows ['090' '058' '048'] with missing score
#   warnings.warn(f'Dropping rows {only_na.index.values} with missing score')

# %%
n_outputs = len(SCORES_TO_USE)

def get_model():
    # simple CNN
    input_layer = keras.layers.Input(shape=(n_timesteps,n_features))
    norm_layer = keras.layers.BatchNormalization()(input_layer)
    cnn_layer = keras.layers.Conv1D(filters=32, kernel_size=3, activation='relu')(norm_layer)
    cnn_layer = keras.layers.Conv1D(filters=32, kernel_size=3, activation='relu')(cnn_layer)
    cnn_layer = keras.layers.MaxPooling1D(pool_size=2)(cnn_layer)
    cnn_layer = keras.layers.Dropout(0.7)(cnn_layer)
    cnn_layer = keras.layers.Conv1D(filters=64, kernel_size=3, activation='relu')(cnn_layer)
    cnn_layer = keras.layers.Conv1D(filters=64, kernel_size=3, activation='relu')(cnn_layer)
    cnn_layer = keras.layers.MaxPooling1D(pool_size=2)(cnn_layer)
    cnn_layer = keras.layers.Dropout(0.7)(cnn_layer)
    cnn_layer = keras.layers.Flatten()(cnn_layer)
    cnn_layer = keras.layers.Dense(100)(cnn_layer)
    output_layer = keras.layers.Dense(n_outputs)(cnn_layer)

    return keras.Model(inputs=input_layer, outputs=output_layer)
get_model().summary()
# Out:
# Model: "model_109"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_110 (InputLayer)       [(None, 501, 42)]         0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 501, 42)           168
# _________________________________________________________________
# conv1d_436 (Conv1D)          (None, 499, 32)           4064
# _________________________________________________________________
# conv1d_437 (Conv1D)          (None, 497, 32)           3104
# _________________________________________________________________
# max_pooling1d_218 (MaxPoolin (None, 248, 32)           0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 248, 32)           0
# _________________________________________________________________
# conv1d_438 (Conv1D)          (None, 246, 64)           6208
# _________________________________________________________________
# conv1d_439 (Conv1D)          (None, 244, 64)           12352
# _________________________________________________________________
# max_pooling1d_219 (MaxPoolin (None, 122, 64)           0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 122, 64)           0
# _________________________________________________________________
# flatten_109 (Flatten)        (None, 7808)              0
# _________________________________________________________________
# dense_218 (Dense)            (None, 100)               780900
# _________________________________________________________________
# dense_219 (Dense)            (None, 4)                 404
# =================================================================
# Total params: 807,200
# Trainable params: 807,116
# Non-trainable params: 84
# _________________________________________________________________

# %% [markdown]
# ## Train network

# %%
def train_model(train_generator):
    model = get_model()
    model.compile(loss='mse', optimizer=keras.optimizers.Adam())
    model.fit(train_generator, epochs=30)
    return model

def train_cross_val(cross_val):
    y_pred = []
    y_test = []
    for i_split, (train_scores, test_scores) in enumerate(cross_val):
        print(f'Fitting for 5-fold split {i_split}')
        train_generator = RawDataGenerator(train_scores, videos_folder=LYING_VIDEOS_DATA_FOLDER)
        test_generator = RawDataGenerator(test_scores, videos_folder=LYING_VIDEOS_DATA_FOLDER)
        model = train_model(train_generator)
        y_pred.append(model.predict(test_generator))
        y_test.append(test_scores)
    y_pred = np.vstack(y_pred)
    y_test = pd.concat(y_test)
    return y_test, y_pred

def evaluate(y_test, y_pred):
    results = []
    for i_score, column in enumerate(y_test):
        mae = mean_absolute_error(y_test.iloc[:, i_score], y_pred[:, i_score])
        results.append({'score': column, 'mae': mae})
    return pd.DataFrame(results)

# %%
results = []
for scorer in SCORERS:
    print(f'Training model for scorer {scorer}')
    selector = MultipleScoreSelector(scores_to_use=SCORES_TO_USE, scorer_to_use=scorer)
    selected_data = selector.transform(scores_df)
    cross_val = cross_validation_generator(selected_data)
    y_test, y_pred = train_cross_val(cross_val)
    results.append((y_test, y_pred))
# Out:
# Training model for scorer 1
# /Users/svenvanderburg/projects/modys-video/src/data_selection.py:24: UserWarning: Dropping rows ['096'] with missing video
#   warnings.warn(f'Dropping rows {missing_ids} with missing video')
# /Users/svenvanderburg/projects/modys-video/src/data_selection.py:34: UserWarning: Dropping rows ['090' '058' '048'] with missing score
#   warnings.warn(f'Dropping rows {only_na.index.values} with missing score')
# Fitting for 5-fold split 0
# Epoch 1/30
# 49/49 [==============================] - 1s 13ms/step - loss: 2.1486
# Epoch 2/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.4031
# Epoch 3/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.2361
# Epoch 4/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.1911
# Epoch 5/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.1455
# Epoch 6/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.1369
# Epoch 7/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.1276
# Epoch 8/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0894
# Epoch 9/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0867
# Epoch 10/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0885
# Epoch 11/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0872
# Epoch 12/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0760
# Epoch 13/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0837
# Epoch 14/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0698
# Epoch 15/30
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0630
# Epoch 16/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0647
# Epoch 17/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0597
# Epoch 18/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0594
# Epoch 19/30
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0596
# Epoch 20/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0547
# Epoch 21/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0608
# Epoch 22/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0536
# Epoch 23/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0527
# Epoch 24/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0547
# Epoch 25/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0498
# Epoch 26/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0413
# Epoch 27/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0520
# Epoch 28/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0419
# Epoch 29/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0416
# Epoch 30/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0401
# Fitting for 5-fold split 1
# Epoch 1/30
# 49/49 [==============================] - 1s 14ms/step - loss: 2.3792
# Epoch 2/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.3269
# Epoch 3/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.2268
# Epoch 4/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.1868
# Epoch 5/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.1289
# Epoch 6/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.1420
# Epoch 7/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.1108
# Epoch 8/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0886
# Epoch 9/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.1000
# Epoch 10/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0713
# Epoch 11/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0779
# Epoch 12/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0684
# Epoch 13/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0613
# Epoch 14/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0527
# Epoch 15/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0627
# Epoch 16/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0715
# Epoch 17/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0683
# Epoch 18/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0567
# Epoch 19/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0602
# Epoch 20/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0432
# Epoch 21/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0556
# Epoch 22/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0445
# Epoch 23/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0615
# Epoch 24/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0592
# Epoch 25/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0420
# Epoch 26/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0360
# Epoch 27/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0434
# Epoch 28/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0380
# Epoch 29/30
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0427
# Epoch 30/30
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0410
# Fitting for 5-fold split 2
# Epoch 1/30
# 50/50 [==============================] - 1s 15ms/step - loss: 2.2392
# Epoch 2/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.3348
# Epoch 3/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.1866
# Epoch 4/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.1542
# Epoch 5/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.1240
# Epoch 6/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.1145
# Epoch 7/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0894
# Epoch 8/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0913
# Epoch 9/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0745
# Epoch 10/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0666
# Epoch 11/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0625
# Epoch 12/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0628
# Epoch 13/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0630
# Epoch 14/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0599
# Epoch 15/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0569
# Epoch 16/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0589
# Epoch 17/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0477
# Epoch 18/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0574
# Epoch 19/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0504
# Epoch 20/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0439
# Epoch 21/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0492
# Epoch 22/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0404
# Epoch 23/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0429
# Epoch 24/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0382
# Epoch 25/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0436
# Epoch 26/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0399
# Epoch 27/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0398
# Epoch 28/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0417
# Epoch 29/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0300
# Epoch 30/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0336
# Fitting for 5-fold split 3
# Epoch 1/30
# 50/50 [==============================] - 1s 14ms/step - loss: 1.5201
# Epoch 2/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.4116
# Epoch 3/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.1577
# Epoch 4/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.1236
# Epoch 5/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.1059
# Epoch 6/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0973
# Epoch 7/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.1023
# Epoch 8/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0965
# Epoch 9/30
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0760
# Epoch 10/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0809
# Epoch 11/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0563
# Epoch 12/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0550
# Epoch 13/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0793
# Epoch 14/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0574
# Epoch 15/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0483
# Epoch 16/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0598
# Epoch 17/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0496
# Epoch 18/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0454
# Epoch 19/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0600
# Epoch 20/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0504
# Epoch 21/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0477
# Epoch 22/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0450
# Epoch 23/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0382
# Epoch 24/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0392
# Epoch 25/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0362
# Epoch 26/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0462
# Epoch 27/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0439
# Epoch 28/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411
# Epoch 29/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0433
# Epoch 30/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0418
# Fitting for 5-fold split 4
# Epoch 1/30
# 50/50 [==============================] - 1s 13ms/step - loss: 3.1927
# Epoch 2/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.5368: 0s - lo
# Epoch 3/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.2666
# Epoch 4/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.2016
# Epoch 5/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.1612
# Epoch 6/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.1332
# Epoch 7/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.1187
# Epoch 8/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.1090
# Epoch 9/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0924
# Epoch 10/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.1039
# Epoch 11/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0762
# Epoch 12/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0887
# Epoch 13/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0774
# Epoch 14/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0886
# Epoch 15/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0581
# Epoch 16/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0688
# Epoch 17/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0533
# Epoch 18/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0555
# Epoch 19/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0485
# Epoch 20/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0517
# Epoch 21/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0540
# Epoch 22/30
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0536
# Epoch 23/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0474
# Epoch 24/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0535
# Epoch 25/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0403
# Epoch 26/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0466
# Epoch 27/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0468
# Epoch 28/30
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0414
# Epoch 29/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0555
# Epoch 30/30
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0382
# Training model for scorer 2
# /Users/svenvanderburg/projects/modys-video/src/data_selection.py:24: UserWarning: Dropping rows ['096'] with missing video
#   warnings.warn(f'Dropping rows {missing_ids} with missing video')
# /Users/svenvanderburg/projects/modys-video/src/data_selection.py:34: UserWarning: Dropping rows [] with missing score
#   warnings.warn(f'Dropping rows {only_na.index.values} with missing score')
# Fitting for 5-fold split 0
# Epoch 1/30
# 37/37 [==============================] - 2s 13ms/step - loss: 5.4524
# Epoch 2/30
# 37/37 [==============================] - 1s 13ms/step - loss: 1.2961
# Epoch 3/30
# 37/37 [==============================] - 1s 13ms/step - loss: 0.5143
# Epoch 4/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.2872
# Epoch 5/30
# 37/37 [==============================] - 1s 14ms/step - loss: 0.2556
# Epoch 6/30
# 37/37 [==============================] - 1s 14ms/step - loss: 0.2347
# Epoch 7/30
# 37/37 [==============================] - 1s 13ms/step - loss: 0.1499
# Epoch 8/30
# 37/37 [==============================] - 1s 13ms/step - loss: 0.1637
# Epoch 9/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1361
# Epoch 10/30
# 37/37 [==============================] - 1s 13ms/step - loss: 0.1113
# Epoch 11/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1127
# Epoch 12/30
# 37/37 [==============================] - 1s 14ms/step - loss: 0.1174
# Epoch 13/30
# 37/37 [==============================] - 1s 14ms/step - loss: 0.1200
# Epoch 14/30
# 37/37 [==============================] - 1s 13ms/step - loss: 0.1019
# Epoch 15/30
# 37/37 [==============================] - 1s 14ms/step - loss: 0.1027
# Epoch 16/30
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0957
# Epoch 17/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0905
# Epoch 18/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0803
# Epoch 19/30
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0789
# Epoch 20/30
# 37/37 [==============================] - 1s 13ms/step - loss: 0.0878
# Epoch 21/30
# 37/37 [==============================] - 1s 13ms/step - loss: 0.0705
# Epoch 22/30
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0752
# Epoch 23/30
# 37/37 [==============================] - 1s 13ms/step - loss: 0.0563
# Epoch 24/30
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0692
# Epoch 25/30
# 37/37 [==============================] - 1s 13ms/step - loss: 0.0567
# Epoch 26/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0621
# Epoch 27/30
# 37/37 [==============================] - 1s 13ms/step - loss: 0.0591
# Epoch 28/30
# 37/37 [==============================] - 1s 13ms/step - loss: 0.0623
# Epoch 29/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0594
# Epoch 30/30
# 37/37 [==============================] - 1s 13ms/step - loss: 0.0432
# Fitting for 5-fold split 1
# Epoch 1/30
# 39/39 [==============================] - 1s 16ms/step - loss: 2.3872
# Epoch 2/30
# 39/39 [==============================] - 1s 14ms/step - loss: 0.3718
# Epoch 3/30
# 39/39 [==============================] - 1s 14ms/step - loss: 0.2052
# Epoch 4/30
# 39/39 [==============================] - 1s 14ms/step - loss: 0.1712
# Epoch 5/30
# 39/39 [==============================] - 1s 16ms/step - loss: 0.1416
# Epoch 6/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.1332
# Epoch 7/30
# 39/39 [==============================] - 1s 15ms/step - loss: 0.1271
# Epoch 8/30
# 39/39 [==============================] - 1s 14ms/step - loss: 0.0966
# Epoch 9/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0856
# Epoch 10/30
# 39/39 [==============================] - 1s 14ms/step - loss: 0.0668
# Epoch 11/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0773
# Epoch 12/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0762
# Epoch 13/30
# 39/39 [==============================] - 1s 14ms/step - loss: 0.0731
# Epoch 14/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0610
# Epoch 15/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0606
# Epoch 16/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0686
# Epoch 17/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0670
# Epoch 18/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0555
# Epoch 19/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0591
# Epoch 20/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0475
# Epoch 21/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0497
# Epoch 22/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0424
# Epoch 23/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0495
# Epoch 24/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0398
# Epoch 25/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0500
# Epoch 26/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0361
# Epoch 27/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0424
# Epoch 28/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0409
# Epoch 29/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0343
# Epoch 30/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0379
# Fitting for 5-fold split 2
# Epoch 1/30
# 39/39 [==============================] - 1s 14ms/step - loss: 2.7407
# Epoch 2/30
# 39/39 [==============================] - 1s 14ms/step - loss: 0.3766
# Epoch 3/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.2651
# Epoch 4/30
# 39/39 [==============================] - 1s 15ms/step - loss: 0.2167
# Epoch 5/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.1468
# Epoch 6/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.1295
# Epoch 7/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.1324
# Epoch 8/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.1044
# Epoch 9/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0974
# Epoch 10/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.1439
# Epoch 11/30
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0976
# Epoch 12/30
# 39/39 [==============================] - 1s 14ms/step - loss: 0.0916
# Epoch 13/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0835
# Epoch 14/30
# 39/39 [==============================] - 1s 14ms/step - loss: 0.0887
# Epoch 15/30
# 39/39 [==============================] - 1s 14ms/step - loss: 0.0702
# Epoch 16/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0701
# Epoch 17/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0686
# Epoch 18/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0496
# Epoch 19/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0593
# Epoch 20/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0527
# Epoch 21/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0649
# Epoch 22/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0653
# Epoch 23/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0609
# Epoch 24/30
# 39/39 [==============================] - 1s 14ms/step - loss: 0.0487
# Epoch 25/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0584
# Epoch 26/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0563
# Epoch 27/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0550
# Epoch 28/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0352
# Epoch 29/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0377
# Epoch 30/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0472
# Fitting for 5-fold split 3
# Epoch 1/30
# 39/39 [==============================] - 1s 15ms/step - loss: 1.7126
# Epoch 2/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.5760
# Epoch 3/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.2380
# Epoch 4/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.2042
# Epoch 5/30
# 39/39 [==============================] - 1s 14ms/step - loss: 0.1939
# Epoch 6/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.1456
# Epoch 7/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.1238
# Epoch 8/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.1335
# Epoch 9/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.1081
# Epoch 10/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0797
# Epoch 11/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0930
# Epoch 12/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0753
# Epoch 13/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0830
# Epoch 14/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0958
# Epoch 15/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0811
# Epoch 16/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0788
# Epoch 17/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0714
# Epoch 18/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0619
# Epoch 19/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0705
# Epoch 20/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0597
# Epoch 21/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0544
# Epoch 22/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0579
# Epoch 23/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0575
# Epoch 24/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0575
# Epoch 25/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0573
# Epoch 26/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0584
# Epoch 27/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0552
# Epoch 28/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0434
# Epoch 29/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0549
# Epoch 30/30
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0542
# Fitting for 5-fold split 4
# Epoch 1/30
# 38/38 [==============================] - 1s 14ms/step - loss: 5.0988
# Epoch 2/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.8276
# Epoch 3/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.4498
# Epoch 4/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.3689
# Epoch 5/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.2420
# Epoch 6/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.2115
# Epoch 7/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.2089
# Epoch 8/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.1719
# Epoch 9/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.1555
# Epoch 10/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.1581
# Epoch 11/30
# 38/38 [==============================] - 0s 13ms/step - loss: 0.1585
# Epoch 12/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.1078
# Epoch 13/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.1003
# Epoch 14/30
# 38/38 [==============================] - 0s 13ms/step - loss: 0.1106
# Epoch 15/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.1089
# Epoch 16/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0927
# Epoch 17/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0984
# Epoch 18/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0915
# Epoch 19/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0811
# Epoch 20/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0812
# Epoch 21/30
# 38/38 [==============================] - 0s 13ms/step - loss: 0.0875
# Epoch 22/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0865
# Epoch 23/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0929
# Epoch 24/30
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0568
# Epoch 25/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0683
# Epoch 26/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0595
# Epoch 27/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0612
# Epoch 28/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0781
# Epoch 29/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0648
# Epoch 30/30
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0508
# Training model for scorer 3
# /Users/svenvanderburg/projects/modys-video/src/data_selection.py:34: UserWarning: Dropping rows [] with missing score
#   warnings.warn(f'Dropping rows {only_na.index.values} with missing score')
# Fitting for 5-fold split 0
# Epoch 1/30
# 36/36 [==============================] - 1s 17ms/step - loss: 5.2329
# Epoch 2/30
# 36/36 [==============================] - 1s 16ms/step - loss: 0.6981
# Epoch 3/30
# 36/36 [==============================] - 1s 15ms/step - loss: 0.5101
# Epoch 4/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.2743
# Epoch 5/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.1776
# Epoch 6/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.1644
# Epoch 7/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.1307
# Epoch 8/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.1487
# Epoch 9/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.1434
# Epoch 10/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.1013
# Epoch 11/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0972
# Epoch 12/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0994
# Epoch 13/30
# 36/36 [==============================] - 1s 14ms/step - loss: 0.1154
# Epoch 14/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0921
# Epoch 15/30
# 36/36 [==============================] - 1s 14ms/step - loss: 0.0864
# Epoch 16/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0859
# Epoch 17/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0881
# Epoch 18/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0800
# Epoch 19/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0929
# Epoch 20/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0570
# Epoch 21/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0726
# Epoch 22/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0536
# Epoch 23/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0656
# Epoch 24/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0702
# Epoch 25/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0627
# Epoch 26/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0459
# Epoch 27/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0638
# Epoch 28/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0577
# Epoch 29/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0488
# Epoch 30/30
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0501
# Fitting for 5-fold split 1
# Epoch 1/30
# 37/37 [==============================] - 1s 15ms/step - loss: 2.6353
# Epoch 2/30
# 37/37 [==============================] - 1s 14ms/step - loss: 1.0843
# Epoch 3/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.4834
# Epoch 4/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.2758
# Epoch 5/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1947
# Epoch 6/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1466
# Epoch 7/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1390
# Epoch 8/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1417
# Epoch 9/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1219
# Epoch 10/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1206
# Epoch 11/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1115
# Epoch 12/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0810
# Epoch 13/30
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0896
# Epoch 14/30
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0746
# Epoch 15/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0801
# Epoch 16/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0644
# Epoch 17/30
# 37/37 [==============================] - 1s 13ms/step - loss: 0.0732
# Epoch 18/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0859
# Epoch 19/30
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0839
# Epoch 20/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0785
# Epoch 21/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0601
# Epoch 22/30
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0488
# Epoch 23/30
# 37/37 [==============================] - 1s 13ms/step - loss: 0.0587
# Epoch 24/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0617
# Epoch 25/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0448
# Epoch 26/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0437
# Epoch 27/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0560
# Epoch 28/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0432
# Epoch 29/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0596
# Epoch 30/30
# 37/37 [==============================] - 1s 13ms/step - loss: 0.0493
# Fitting for 5-fold split 2
# Epoch 1/30
# 37/37 [==============================] - 1s 16ms/step - loss: 2.8919
# Epoch 2/30
# 37/37 [==============================] - 1s 15ms/step - loss: 0.4899
# Epoch 3/30
# 37/37 [==============================] - 1s 14ms/step - loss: 0.2622
# Epoch 4/30
# 37/37 [==============================] - 1s 13ms/step - loss: 0.1703
# Epoch 5/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1190
# Epoch 6/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1249
# Epoch 7/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1211
# Epoch 8/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1022
# Epoch 9/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0807
# Epoch 10/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0776
# Epoch 11/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0899
# Epoch 12/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0872
# Epoch 13/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0525
# Epoch 14/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0566
# Epoch 15/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0637
# Epoch 16/30
# 37/37 [==============================] - 0s 12ms/step - loss: 0.0565
# Epoch 17/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0501
# Epoch 18/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0421
# Epoch 19/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0540
# Epoch 20/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0648
# Epoch 21/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0495
# Epoch 22/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0392
# Epoch 23/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0485
# Epoch 24/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0377
# Epoch 25/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0473
# Epoch 26/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0478
# Epoch 27/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0385
# Epoch 28/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0410
# Epoch 29/30
# 37/37 [==============================] - 1s 13ms/step - loss: 0.0448
# Epoch 30/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0447
# Fitting for 5-fold split 3
# Epoch 1/30
# 37/37 [==============================] - 1s 16ms/step - loss: 4.3107
# Epoch 2/30
# 37/37 [==============================] - 1s 16ms/step - loss: 0.5467
# Epoch 3/30
# 37/37 [==============================] - 1s 14ms/step - loss: 0.2903
# Epoch 4/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.2163
# Epoch 5/30
# 37/37 [==============================] - 1s 13ms/step - loss: 0.2117
# Epoch 6/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1781
# Epoch 7/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1269
# Epoch 8/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1352
# Epoch 9/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1331
# Epoch 10/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1172
# Epoch 11/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1257
# Epoch 12/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1076
# Epoch 13/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1009
# Epoch 14/30
# 37/37 [==============================] - 1s 13ms/step - loss: 0.0985
# Epoch 15/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0995
# Epoch 16/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1073
# Epoch 17/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0936
# Epoch 18/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1029
# Epoch 19/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0905
# Epoch 20/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0821
# Epoch 21/30
# 37/37 [==============================] - 1s 13ms/step - loss: 0.0788
# Epoch 22/30
# 37/37 [==============================] - 0s 12ms/step - loss: 0.0747
# Epoch 23/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0889
# Epoch 24/30
# 37/37 [==============================] - 0s 12ms/step - loss: 0.0877
# Epoch 25/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0943
# Epoch 26/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0801
# Epoch 27/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0656
# Epoch 28/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0661
# Epoch 29/30
# 37/37 [==============================] - 0s 12ms/step - loss: 0.0574
# Epoch 30/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0523
# Fitting for 5-fold split 4
# Epoch 1/30
# 37/37 [==============================] - 1s 15ms/step - loss: 3.9883
# Epoch 2/30
# 37/37 [==============================] - 1s 14ms/step - loss: 0.9533
# Epoch 3/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.3751
# Epoch 4/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.2270
# Epoch 5/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.2176
# Epoch 6/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1570
# Epoch 7/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1489
# Epoch 8/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1252
# Epoch 9/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1145
# Epoch 10/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1099
# Epoch 11/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1327
# Epoch 12/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1019
# Epoch 13/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.1007
# Epoch 14/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0741
# Epoch 15/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0822
# Epoch 16/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0855
# Epoch 17/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0928
# Epoch 18/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0837
# Epoch 19/30
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0718
# Epoch 20/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0635
# Epoch 21/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0800
# Epoch 22/30
# 37/37 [==============================] - 1s 13ms/step - loss: 0.0622
# Epoch 23/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0759
# Epoch 24/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0683
# Epoch 25/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0673
# Epoch 26/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0685
# Epoch 27/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0679
# Epoch 28/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0600
# Epoch 29/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0669
# Epoch 30/30
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0556

# %%
for scorer, (y_test, y_pred) in zip(SCORERS, results):
    print(f'results for scorer {scorer}')
    print(evaluate(y_test, y_pred))
# Out:
# results for scorer 1
#                score       mae
# 0  D_RLP_R_tD_pscore  0.335920
# 1  D_LLP_R_tD_pscore  0.379423
# 2  D_RLP_R_tA_pscore  0.261640
# 3  D_LLP_R_tA_pscore  0.302673
# results for scorer 2
#                score       mae
# 0  D_RLP_R_tD_pscore  0.342937
# 1  D_LLP_R_tD_pscore  0.377326
# 2  D_RLP_R_tA_pscore  0.306030
# 3  D_LLP_R_tA_pscore  0.276037
# results for scorer 3
#                score       mae
# 0  D_RLP_R_tD_pscore  0.605735
# 1  D_LLP_R_tD_pscore  0.614131
# 2  D_RLP_R_tA_pscore  0.555853
# 3  D_LLP_R_tA_pscore  0.567253
